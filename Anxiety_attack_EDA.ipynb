# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path= ("anxiety_attack_dataset.csv")

# %%
df=pd.read_csv("anxiety_attack_dataset.csv")

# %%
df.shape
# Out:
# (12000, 20)

# %%
df.head()
# Out:
#    ID  Age  Gender Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 0   1   56  Female      Other          9.6                           8.3
# 1   2   46    Male    Teacher          6.4                           7.3
# 2   3   32  Female     Doctor          6.9                           1.0
# 3   4   60    Male     Doctor          9.2                           3.7
# 4   5   25    Male    Student          9.2                           2.5
#
#    Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# 0                       175                                  6      No
# 1                        97                                  6      No
# 2                       467                                 14      No
# 3                       471                                 16      No
# 4                       364                                  2      No
#
#   Family History of Anxiety  Stress Level (1-10)  \
# ...

# %%
df.describe()
# Out:
#                 ID          Age   Sleep Hours  Physical Activity (hrs/week)  \
# count  12000.00000  12000.00000  12000.000000                  12000.000000
# mean    6000.50000     40.96675      6.482650                      5.030892
# std     3464.24595     13.47328      2.014885                      2.889000
# min        1.00000     18.00000      3.000000                      0.000000
# 25%     3000.75000     29.00000      4.800000                      2.500000
# 50%     6000.50000     41.00000      6.500000                      5.000000
# 75%     9000.25000     53.00000      8.200000                      7.525000
# max    12000.00000     64.00000     10.000000                     10.000000
#
#        Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week)  \
# count              12000.000000                       12000.000000
# mean                 246.696083                           9.492833
# std                  144.487071                           5.769364
# ...

# %%
df.drop_duplicates()
# Out:
#           ID  Age  Gender Occupation  Sleep Hours  \
# 0          1   56  Female      Other          9.6
# 1          2   46    Male    Teacher          6.4
# 2          3   32  Female     Doctor          6.9
# 3          4   60    Male     Doctor          9.2
# 4          5   25    Male    Student          9.2
# ...      ...  ...     ...        ...          ...
# 11995  11996   28    Male   Engineer          4.4
# 11996  11997   49  Female     Doctor          9.9
# 11997  11998   23  Female    Student          9.8
# 11998  11999   52    Male    Teacher          5.9
# 11999  12000   50    Male    Teacher          6.6
#
#        Physical Activity (hrs/week)  Caffeine Intake (mg/day)  \
# 0                               8.3                       175
# 1                               7.3                        97
# 2                               1.0                       467
# 3                               3.7                       471
# ...

# %%
df.shape
# Out:
# (12000, 20)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (12000, 20)

# %%
cdf=(df[["Age","Sleep Hours",'Physical Activity (hrs/week)','Caffeine Intake (mg/day)','Severity of Anxiety Attack (1-10)']])
cdf.head()
# Out:
#    Age  Sleep Hours  Physical Activity (hrs/week)  Caffeine Intake (mg/day)  \
# 0   56          9.6                           8.3                       175
# 1   46          6.4                           7.3                        97
# 2   32          6.9                           1.0                       467
# 3   60          9.2                           3.7                       471
# 4   25          9.2                           2.5                       364
#
#    Severity of Anxiety Attack (1-10)
# 0                                 10
# 1                                  8
# 2                                  5
# 3                                  8
# 4                                  1

# %%
viz=cdf[['Age','Sleep Hours','Physical Activity (hrs/week)','Caffeine Intake (mg/day)','Severity of Anxiety Attack (1-10)']]
viz.hist(figsize=(10,10))
plt.show()

# %%
plt.scatter(cdf.Age,cdf['Severity of Anxiety Attack (1-10)'],color='blue')
plt.xlabel('Age')
plt.ylabel('Severity of Anxiety Attack (1-10)')
plt.show()

# %%
train_df=df.sample(frac=0.8,random_state=42)
test_df=df.drop(train_df.index)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9600 entries, 1935 to 5330
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ID                                 9600 non-null   int64
#  1   Age                                9600 non-null   int64
#  2   Gender                             9600 non-null   object
#  3   Occupation                         9600 non-null   object
#  4   Sleep Hours                        9600 non-null   float64
#  5   Physical Activity (hrs/week)       9600 non-null   float64
#  6   Caffeine Intake (mg/day)           9600 non-null   int64
#  7   Alcohol Consumption (drinks/week)  9600 non-null   int64
#  8   Smoking                            9600 non-null   object
#  9   Family History of Anxiety          9600 non-null   object
#  10  Stress Level (1-10)                9600 non-null   int64
# ...

# %%
train_df.reset_index(inplace=True)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9600 entries, 0 to 9599
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   index                              9600 non-null   int64
#  1   ID                                 9600 non-null   int64
#  2   Age                                9600 non-null   int64
#  3   Gender                             9600 non-null   object
#  4   Occupation                         9600 non-null   object
#  5   Sleep Hours                        9600 non-null   float64
#  6   Physical Activity (hrs/week)       9600 non-null   float64
#  7   Caffeine Intake (mg/day)           9600 non-null   int64
#  8   Alcohol Consumption (drinks/week)  9600 non-null   int64
#  9   Smoking                            9600 non-null   object
#  10  Family History of Anxiety          9600 non-null   object
# ...

# %%
neumerical_data = [features for features in df.columns if df[features].dtype != "object"]

# %%
continuos_data = [features for features in df.columns if df[features].dtype == "object"]

# %%
neumerical_data
# Out:
# ['ID',
#  'Age',
#  'Sleep Hours',
#  'Physical Activity (hrs/week)',
#  'Caffeine Intake (mg/day)',
#  'Alcohol Consumption (drinks/week)',
#  'Stress Level (1-10)',
#  'Heart Rate (bpm during attack)',
#  'Breathing Rate (breaths/min)',
#  'Sweating Level (1-5)',
#  'Therapy Sessions (per month)',
#  'Diet Quality (1-10)',
#  'Severity of Anxiety Attack (1-10)']

# %%
continuos_data
# Out:
# ['Gender',
#  'Occupation',
#  'Smoking',
#  'Family History of Anxiety',
#  'Dizziness',
#  'Medication',
#  'Recent Major Life Event']

# %%
train_df[neumerical_data].corr()
# Out:
#                                          ID       Age  Sleep Hours  \
# ID                                 1.000000 -0.026906    -0.002770
# Age                               -0.026906  1.000000     0.006261
# Sleep Hours                       -0.002770  0.006261     1.000000
# Physical Activity (hrs/week)      -0.007701 -0.010039    -0.000007
# Caffeine Intake (mg/day)          -0.013101 -0.009103     0.002403
# Alcohol Consumption (drinks/week)  0.005686 -0.004482     0.025763
# Stress Level (1-10)               -0.000785  0.019895    -0.002524
# Heart Rate (bpm during attack)    -0.014859 -0.017551    -0.016608
# Breathing Rate (breaths/min)       0.001252  0.012683     0.000370
# Sweating Level (1-5)               0.012795 -0.009454     0.009858
# Therapy Sessions (per month)       0.019441  0.014196     0.008477
# Diet Quality (1-10)                0.006332  0.008668     0.006069
# Severity of Anxiety Attack (1-10) -0.015681 -0.020096    -0.003858
#
# ...

# %%
train_df[neumerical_data].skew()
# Out:
# ID                                   0.007257
# Age                                 -0.005754
# Sleep Hours                          0.027716
# Physical Activity (hrs/week)        -0.007447
# Caffeine Intake (mg/day)             0.018903
# Alcohol Consumption (drinks/week)    0.003344
# Stress Level (1-10)                  0.016904
# Heart Rate (bpm during attack)       0.000267
# Breathing Rate (breaths/min)         0.008158
# Sweating Level (1-5)                 0.020995
# Therapy Sessions (per month)         0.001553
# Diet Quality (1-10)                  0.025600
# Severity of Anxiety Attack (1-10)   -0.009931
# dtype: float64

# %%
# sns.heatmap(train_df[neumerical_data].corr(),annot=True)
sns.heatmap(df[neumerical_data].corr(), annot=True, fmt=".2f", cmap='viridis', linewidths=1.5, annot_kws={"size": 6}, cbar=True)
# Out:
# <Axes: >

# %%
import plotly.express as px
fig = px.scatter_3d(df,"Age","Sleep Hours","Severity of Anxiety Attack (1-10)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
gender_data=df['Gender']
plt.pie(gender_data.value_counts(),labels=gender_data.value_counts().index,autopct='%1.2f%%')
plt.show()
